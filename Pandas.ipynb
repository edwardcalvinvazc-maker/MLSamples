# %% [markdown]
# <a href="https://colab.research.google.com/github/edwardcalvinvazc-maker/MLSamples/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
series_ds = pd.Series(['Bmw','Toyota','Tata','Nissan','Benz'])
series_ds[5] = 'Nissan'
colours_ds = pd.Series(['Blue','Green','Black','White','Pink'])
car_data_ds = pd.DataFrame ({'Car Brand' : series_ds , 'Colours' : colours_ds})
car_data_ds
# Out:
#   Car Brand Colours
# 0       Bmw    Blue
# 1    Toyota   Green
# 2      Tata   Black
# 3    Nissan   White
# 4      Benz    Pink
# 5    Nissan     NaN

# %%
# import data from csv
import pandas as pd
salary_dataset = pd.read_csv('/content/salary_dataset.csv')
salary_dataset.to_csv('exported-salary-dateset.csv')
salary_dataset.to_csv('exported-salary-dateset.csv',index = False)
salary_dataset.dtypes
salary_columns = salary_dataset.columns
salary_columns
salary_dataset.index
salary_dataset.describe()
# Out:
#        Unnamed: 0  YearsExperience         Salary
# count   30.000000        30.000000      30.000000
# mean    14.500000         5.413333   76004.000000
# std      8.803408         2.837888   27414.429785
# min      0.000000         1.200000   37732.000000
# 25%      7.250000         3.300000   56721.750000
# 50%     14.500000         4.800000   65238.000000
# 75%     21.750000         7.800000  100545.750000
# max     29.000000        10.600000  122392.000000

# %%
salary_dataset.dtypes
# Out:
# Unnamed: 0           int64
# YearsExperience    float64
# Salary             float64
# dtype: object

# %%
salary_columns
# Out:
# Index(['Unnamed: 0', 'YearsExperience', 'Salary'], dtype='object')

# %%
salary_dataset.index
# Out:
# RangeIndex(start=0, stop=30, step=1)

# %%
salary_dataset.describe()
# Out:
#        Unnamed: 0  YearsExperience         Salary
# count   30.000000        30.000000      30.000000
# mean    14.500000         5.413333   76004.000000
# std      8.803408         2.837888   27414.429785
# min      0.000000         1.200000   37732.000000
# 25%      7.250000         3.300000   56721.750000
# 50%     14.500000         4.800000   65238.000000
# 75%     21.750000         7.800000  100545.750000
# max     29.000000        10.600000  122392.000000

# %%
salary_dataset.info
# Out:
# <bound method DataFrame.info of     Unnamed: 0  YearsExperience    Salary
# 0            0              1.2   39344.0
# 1            1              1.4   46206.0
# 2            2              1.6   37732.0
# 3            3              2.1   43526.0
# 4            4              2.3   39892.0
# 5            5              3.0   56643.0
# 6            6              3.1   60151.0
# 7            7              3.3   54446.0
# 8            8              3.3   64446.0
# 9            9              3.8   57190.0
# 10          10              4.0   63219.0
# 11          11              4.1   55795.0
# 12          12              4.1   56958.0
# 13          13              4.2   57082.0
# 14          14              4.6   61112.0
# 15          15              5.0   67939.0
# 16          16              5.2   66030.0
# 17          17              5.4   83089.0
# 18          18              6.0   81364.0
# 19          19              6.1   93941.0
# 20          20              6.9   91739.0
# ...

# %%
len(salary_dataset)
# Out:
# 30

# %%
salary_dataset.sum()
# Out:
# Unnamed: 0             435.0
# YearsExperience        162.4
# Salary             2280120.0
# dtype: float64

# %%
salary_dataset ['YearsExperience'].sum()
# Out:
# np.float64(162.39999999999998)

# %%
salary_dataset['Salary'].sum()
# Out:
# np.float64(2280120.0)

# %%
salary_dataset.head()
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %%
salary_dataset.tail()
# Out:
#     Unnamed: 0  YearsExperience    Salary
# 25          25              9.1  105583.0
# 26          26              9.6  116970.0
# 27          27              9.7  112636.0
# 28          28             10.4  122392.0
# 29          29             10.6  121873.0

# %%
series_ds = pd.Series
langs = pd.Series(['Pixel','Apple','Iqoo','Oneplus','Nothing'], index = [2,3,4,1,5])
langs.loc[3],langs.iloc[4]
# Out:
# ('Apple', 'Nothing')

# %%
series_ds = pd.Series
langs = pd.Series (salary_dataset ['Salary'])
langs.loc[13],langs.iloc[:11]
# Out:
# (np.float64(57082.0),
#  0     39344.0
#  1     46206.0
#  2     37732.0
#  3     43526.0
#  4     39892.0
#  5     56643.0
#  6     60151.0
#  7     54446.0
#  8     64446.0
#  9     57190.0
#  10    63219.0
#  Name: Salary, dtype: float64)

# %%
salary_dataset['Salary']
salary_dataset.Salary[:11]
# Out:
# 0     39344.0
# 1     46206.0
# 2     37732.0
# 3     43526.0
# 4     39892.0
# 5     56643.0
# 6     60151.0
# 7     54446.0
# 8     64446.0
# 9     57190.0
# 10    63219.0
# Name: Salary, dtype: float64

# %%
salary_dataset['Salary']
salary_dataset.Salary
salary_dataset[salary_dataset['Salary'] == '61112']
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, YearsExperience, Salary]
# Index: []

# %%
import matplotlib.pyplot as plt
salary_dataset.plot()
# Out:
# <Axes: >

# %%
salary_dataset.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
salary_dataset = pd.read_csv('exported-salary-dateset.csv')

# %%
name_list = pd.read_csv('/content/polish_names.csv')
name_list['Maria'].str.lower().head()
# Out:
# 0    krystyna
# 1        anna
# 2     barbara
# 3      teresa
# 4    elżbieta
# Name: Maria, dtype: object

# %%
name_list['Maria'].tail()
# Out:
# 294       Jagoda
# 295         Elza
# 296      Ludwina
# 297     Józefina
# 298    Zbigniewa
# Name: Maria, dtype: object

# %%
name_list['Maria'].head()
# Out:
# 0    Krystyna
# 1        Anna
# 2     Barbara
# 3      Teresa
# 4    Elżbieta
# Name: Maria, dtype: object

# %%
name_list.drop(0)
# Out:
#          Maria
# 1         Anna
# 2      Barbara
# 3       Teresa
# 4     Elżbieta
# 5       Janina
# ..         ...
# 294     Jagoda
# 295       Elza
# 296    Ludwina
# 297   Józefina
# 298  Zbigniewa
#
# [298 rows x 1 columns]

# %%
name_list.sample(frac=0.5)
# Out:
#           Maria
# 27     Wiesława
# 231       Erika
# 38   Aleksandra
# 75      Zuzanna
# 144       Eliza
# ..          ...
# 143      Donata
# 175   Kunegunda
# 297    Józefina
# 177       Sonia
# 158     Klaudia
#
# [150 rows x 1 columns]

# %%
name_list.reset_index(drop=True,inplace=True)
name_list
# Out:
#          Maria
# 0     Krystyna
# 1         Anna
# 2      Barbara
# 3       Teresa
# 4     Elżbieta
# ..         ...
# 294     Jagoda
# 295       Elza
# 296    Ludwina
# 297   Józefina
# 298  Zbigniewa
#
# [299 rows x 1 columns]
